# %%
import pandas as pd

# %%
df = pd.read_csv("/lustre/scratch126/casm/team274sb/lr26/pepper-tumor1B01/annotated_normalized_tumor_outputt2t.vcf",
                 sep="\t",
                 comment="#",
                 dtype="str",
                 header=None,
                 names=["chr","pos","id","ref","alt","qual","filter","info","format","sample"])
df
# Out:
#           chr       pos id ref alt  qual   filter info             format  \
# 0        chr1      4427  .   A   C  12.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 1        chr1      4438  .   C   T  10.8     PASS    .  GT:GQ:DP:AD:VAF:C
# 2        chr1      4440  .   G   A  11.3     PASS    .  GT:GQ:DP:AD:VAF:C
# 3        chr1      4464  .   C   T   6.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 4        chr1      4501  .   T   C  13.7     PASS    .  GT:GQ:DP:AD:VAF:C
# ...       ...       ... ..  ..  ..   ...      ...  ...                ...
# 7598646  chrY  62456021  .   G   T   6.5     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598647  chrY  62456075  .   G   T  13.4     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598648  chrY  62456143  .  AG   A   2.6  refCall    .  GT:GQ:DP:AD:VAF:C
# 7598649  chrY  62456186  .  AG   A   6.1     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598650  chrY  62456282  .  AG   A    10     PASS    .  GT:GQ:DP:AD:VAF:C
#
#                         sample
# 0              1/1:11:3:3:1:DV
# 1              1/1:10:3:3:1:DV
# 2              1/1:11:3:3:1:DV
# 3        0/1:6:3:2:0.666667:DV
# 4              1/1:13:3:3:1:DV
# ...                        ...
# 7598646         1/1:5:2:2:1:DV
# 7598647         1/1:6:2:2:1:DV
# 7598648         ./.:3:2:2:1:DV
# 7598649         1/1:4:2:2:1:DV
# 7598650         1/1:6:2:2:1:DV
#
# [7598651 rows x 10 columns]

# %%
print("INFO field of first variant:")
print(df.loc[0, "info"])
df_filtered = df.copy()
# Out:
# INFO field of first variant:
# .

# %%
def parse_sample_format(format_str, sample_str):
    """
    Parses FORMAT and SAMPLE fields of a VCF into a dictionary
    Handles numeric parsing and multi-allelic values robustly
    """
    keys = format_str.split(":")
    values = sample_str.split(":")
    sample_dict = dict(zip(keys, values))

    # Parse GT
    sample_dict["GT"] = sample_dict.get("GT", "")

    # Parse DP
    try:
        sample_dict["DP"] = int(sample_dict.get("DP", 0))
    except ValueError:
        sample_dict["DP"] = 0

    # Parse AD
    ad_val = sample_dict.get("AD", "0")
    if "," in ad_val:
        try:
            ad_list = [int(a) for a in ad_val.split(",") if a.isdigit()]
            sample_dict["AD"] = sum(ad_list[1:])  # Only ALT allele depth(s)
        except:
            sample_dict["AD"] = 0
    else:
        sample_dict["AD"] = int(ad_val) if ad_val.isdigit() else 0

    # Parse VAF (handle multiple values by taking max)
    vaf_val = sample_dict.get("VAF", "0.0")
    try:
        if "," in vaf_val:
            vaf_list = [float(v) for v in vaf_val.split(",") if v]
            sample_dict["VAF"] = max(vaf_list) if vaf_list else 0.0
        else:
            sample_dict["VAF"] = float(vaf_val)
    except:
        sample_dict["VAF"] = 0.0

    return sample_dict


def get_genotype_from_GT(gt_str):
    """
    Determines genotype type based on GT field
    """
    alleles = gt_str.replace('|', '/').split('/')
    if len(alleles) == 2:
        if alleles[0] == alleles[1]:
            return "homozygous"
        else:
            return "heterozygous"
    return "unknown"

def extract_gt(sample_str, format_str):
    keys = format_str.split(":")
    values = sample_str.split(":")
    format_dict = dict(zip(keys, values))
    gt = format_dict.get("GT", "")
    return get_genotype_from_GT(gt)

def filter_variant_by_sample(sample_dict, min_dp=10, min_ad=3, min_vaf=0.1):
    """
    Apply basic quality filters on depth, allele depth, and VAF
    """
    dp = sample_dict.get("DP", 0)
    ad = sample_dict.get("AD", 0)
    vaf = sample_dict.get("VAF", 0.0)
    
    return (dp >= min_dp) and (ad >= min_ad) and (vaf >= min_vaf)

def get_cosmic_annotation(info_str):
    """
    Parses a COSMIC-style INFO field and returns a dictionary of annotations.
    This assumes the INFO string is formatted as key=value;key=value;...
    """
    info_dict = {}
    for entry in info_str.split(";"):
        if "=" in entry:
            key, value = entry.split("=", 1)
            info_dict[key] = value
    return info_dict


def extract_gene(annotation):
    return annotation.get("GENE_SYMBOL")

def extract_protein_position(annotation):
    return annotation.get("MUTATION_AA")

def extract_mutation_description(annotation):
    return annotation.get("MUTATION_DESCRIPTION") or annotation.get("rsid")

# %%
# Extract sample info
df_filtered["sample_info"] = df_filtered.apply(lambda row: parse_sample_format(row["format"], row["sample"]), axis=1)

# Add specific fields as separate columns
df_filtered["DP"]  = df_filtered["sample_info"].apply(lambda x: x["DP"])
df_filtered["AD"]  = df_filtered["sample_info"].apply(lambda x: x["AD"])
df_filtered["VAF"] = df_filtered["sample_info"].apply(lambda x: x["VAF"])
df_filtered["GT"]  = df_filtered["sample_info"].apply(lambda x: x["GT"])
df_filtered["genotype"] = df_filtered["GT"].apply(get_genotype_from_GT)

# Apply filtering
df_filtered["pass_sample_filters"] = df_filtered["sample_info"].apply(filter_variant_by_sample)

# Extract VEP annotations
df_filtered["cosmic_ann"] = df_filtered["info"].apply(get_cosmic_annotation)

df_filtered["gene"] = df_filtered["cosmic_ann"].apply(extract_gene)
df_filtered["protein_position"] = df_filtered["cosmic_ann"].apply(extract_protein_position)
df_filtered["mutation_description"] = df_filtered["cosmic_ann"].apply(extract_mutation_description)

# %%
df_filtered
# Out:
#           chr       pos id ref alt  qual   filter info             format  \
# 0        chr1      4427  .   A   C  12.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 1        chr1      4438  .   C   T  10.8     PASS    .  GT:GQ:DP:AD:VAF:C
# 2        chr1      4440  .   G   A  11.3     PASS    .  GT:GQ:DP:AD:VAF:C
# 3        chr1      4464  .   C   T   6.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 4        chr1      4501  .   T   C  13.7     PASS    .  GT:GQ:DP:AD:VAF:C
# ...       ...       ... ..  ..  ..   ...      ...  ...                ...
# 7598646  chrY  62456021  .   G   T   6.5     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598647  chrY  62456075  .   G   T  13.4     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598648  chrY  62456143  .  AG   A   2.6  refCall    .  GT:GQ:DP:AD:VAF:C
# 7598649  chrY  62456186  .  AG   A   6.1     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598650  chrY  62456282  .  AG   A    10     PASS    .  GT:GQ:DP:AD:VAF:C
#
#                         sample  ... DP  AD       VAF   GT      genotype  \
# 0              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 1              1/1:10:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 2              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 3        0/1:6:3:2:0.666667:DV  ...  3   2  0.666667  0/1  heterozygous
# 4              1/1:13:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# ...                        ...  ... ..  ..       ...  ...           ...
# 7598646         1/1:5:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598647         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598648         ./.:3:2:2:1:DV  ...  2   2  1.000000  ./.    homozygous
# 7598649         1/1:4:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598650         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
#
#         pass_sample_filters  cosmic_ann  gene protein_position  \
# 0                     False          {}  None             None
# 1                     False          {}  None             None
# 2                     False          {}  None             None
# 3                     False          {}  None             None
# 4                     False          {}  None             None
# ...                     ...         ...   ...              ...
# 7598646               False          {}  None             None
# 7598647               False          {}  None             None
# 7598648               False          {}  None             None
# 7598649               False          {}  None             None
# 7598650               False          {}  None             None
#
#         mutation_description
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 7598646                 None
# 7598647                 None
# 7598648                 None
# 7598649                 None
# 7598650                 None
#
# [7598651 rows x 21 columns]

# %%
df_intronless = df_filtered[df_filtered["mutation_description"] != "intron_variant"]
df_intronless
# Out:
#           chr       pos id ref alt  qual   filter info             format  \
# 0        chr1      4427  .   A   C  12.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 1        chr1      4438  .   C   T  10.8     PASS    .  GT:GQ:DP:AD:VAF:C
# 2        chr1      4440  .   G   A  11.3     PASS    .  GT:GQ:DP:AD:VAF:C
# 3        chr1      4464  .   C   T   6.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 4        chr1      4501  .   T   C  13.7     PASS    .  GT:GQ:DP:AD:VAF:C
# ...       ...       ... ..  ..  ..   ...      ...  ...                ...
# 7598646  chrY  62456021  .   G   T   6.5     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598647  chrY  62456075  .   G   T  13.4     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598648  chrY  62456143  .  AG   A   2.6  refCall    .  GT:GQ:DP:AD:VAF:C
# 7598649  chrY  62456186  .  AG   A   6.1     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598650  chrY  62456282  .  AG   A    10     PASS    .  GT:GQ:DP:AD:VAF:C
#
#                         sample  ... DP  AD       VAF   GT      genotype  \
# 0              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 1              1/1:10:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 2              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 3        0/1:6:3:2:0.666667:DV  ...  3   2  0.666667  0/1  heterozygous
# 4              1/1:13:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# ...                        ...  ... ..  ..       ...  ...           ...
# 7598646         1/1:5:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598647         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598648         ./.:3:2:2:1:DV  ...  2   2  1.000000  ./.    homozygous
# 7598649         1/1:4:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598650         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
#
#         pass_sample_filters  cosmic_ann  gene protein_position  \
# 0                     False          {}  None             None
# 1                     False          {}  None             None
# 2                     False          {}  None             None
# 3                     False          {}  None             None
# 4                     False          {}  None             None
# ...                     ...         ...   ...              ...
# 7598646               False          {}  None             None
# 7598647               False          {}  None             None
# 7598648               False          {}  None             None
# 7598649               False          {}  None             None
# 7598650               False          {}  None             None
#
#         mutation_description
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 7598646                 None
# 7598647                 None
# 7598648                 None
# 7598649                 None
# 7598650                 None
#
# [7593225 rows x 21 columns]

# %%
df_syn = df_intronless[df_intronless["mutation_description"] != "synonymous_variant"]
df_syn
# Out:
#           chr       pos id ref alt  qual   filter info             format  \
# 0        chr1      4427  .   A   C  12.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 1        chr1      4438  .   C   T  10.8     PASS    .  GT:GQ:DP:AD:VAF:C
# 2        chr1      4440  .   G   A  11.3     PASS    .  GT:GQ:DP:AD:VAF:C
# 3        chr1      4464  .   C   T   6.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 4        chr1      4501  .   T   C  13.7     PASS    .  GT:GQ:DP:AD:VAF:C
# ...       ...       ... ..  ..  ..   ...      ...  ...                ...
# 7598646  chrY  62456021  .   G   T   6.5     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598647  chrY  62456075  .   G   T  13.4     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598648  chrY  62456143  .  AG   A   2.6  refCall    .  GT:GQ:DP:AD:VAF:C
# 7598649  chrY  62456186  .  AG   A   6.1     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598650  chrY  62456282  .  AG   A    10     PASS    .  GT:GQ:DP:AD:VAF:C
#
#                         sample  ... DP  AD       VAF   GT      genotype  \
# 0              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 1              1/1:10:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 2              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 3        0/1:6:3:2:0.666667:DV  ...  3   2  0.666667  0/1  heterozygous
# 4              1/1:13:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# ...                        ...  ... ..  ..       ...  ...           ...
# 7598646         1/1:5:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598647         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598648         ./.:3:2:2:1:DV  ...  2   2  1.000000  ./.    homozygous
# 7598649         1/1:4:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598650         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
#
#         pass_sample_filters  cosmic_ann  gene protein_position  \
# 0                     False          {}  None             None
# 1                     False          {}  None             None
# 2                     False          {}  None             None
# 3                     False          {}  None             None
# 4                     False          {}  None             None
# ...                     ...         ...   ...              ...
# 7598646               False          {}  None             None
# 7598647               False          {}  None             None
# 7598648               False          {}  None             None
# 7598649               False          {}  None             None
# 7598650               False          {}  None             None
#
#         mutation_description
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 7598646                 None
# 7598647                 None
# 7598648                 None
# 7598649                 None
# 7598650                 None
#
# [7592965 rows x 21 columns]

# %%
df3 = df_syn[df_syn["mutation_description"] != "3_prime_UTR_variant"]
df3
# Out:
#           chr       pos id ref alt  qual   filter info             format  \
# 0        chr1      4427  .   A   C  12.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 1        chr1      4438  .   C   T  10.8     PASS    .  GT:GQ:DP:AD:VAF:C
# 2        chr1      4440  .   G   A  11.3     PASS    .  GT:GQ:DP:AD:VAF:C
# 3        chr1      4464  .   C   T   6.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 4        chr1      4501  .   T   C  13.7     PASS    .  GT:GQ:DP:AD:VAF:C
# ...       ...       ... ..  ..  ..   ...      ...  ...                ...
# 7598646  chrY  62456021  .   G   T   6.5     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598647  chrY  62456075  .   G   T  13.4     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598648  chrY  62456143  .  AG   A   2.6  refCall    .  GT:GQ:DP:AD:VAF:C
# 7598649  chrY  62456186  .  AG   A   6.1     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598650  chrY  62456282  .  AG   A    10     PASS    .  GT:GQ:DP:AD:VAF:C
#
#                         sample  ... DP  AD       VAF   GT      genotype  \
# 0              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 1              1/1:10:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 2              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 3        0/1:6:3:2:0.666667:DV  ...  3   2  0.666667  0/1  heterozygous
# 4              1/1:13:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# ...                        ...  ... ..  ..       ...  ...           ...
# 7598646         1/1:5:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598647         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598648         ./.:3:2:2:1:DV  ...  2   2  1.000000  ./.    homozygous
# 7598649         1/1:4:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598650         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
#
#         pass_sample_filters  cosmic_ann  gene protein_position  \
# 0                     False          {}  None             None
# 1                     False          {}  None             None
# 2                     False          {}  None             None
# 3                     False          {}  None             None
# 4                     False          {}  None             None
# ...                     ...         ...   ...              ...
# 7598646               False          {}  None             None
# 7598647               False          {}  None             None
# 7598648               False          {}  None             None
# 7598649               False          {}  None             None
# 7598650               False          {}  None             None
#
#         mutation_description
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 7598646                 None
# 7598647                 None
# 7598648                 None
# 7598649                 None
# 7598650                 None
#
# [7592817 rows x 21 columns]

# %%
df5 = df3[df3["mutation_description"] != "5_prime_UTR_variant"]
df5
# Out:
#           chr       pos id ref alt  qual   filter info             format  \
# 0        chr1      4427  .   A   C  12.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 1        chr1      4438  .   C   T  10.8     PASS    .  GT:GQ:DP:AD:VAF:C
# 2        chr1      4440  .   G   A  11.3     PASS    .  GT:GQ:DP:AD:VAF:C
# 3        chr1      4464  .   C   T   6.2     PASS    .  GT:GQ:DP:AD:VAF:C
# 4        chr1      4501  .   T   C  13.7     PASS    .  GT:GQ:DP:AD:VAF:C
# ...       ...       ... ..  ..  ..   ...      ...  ...                ...
# 7598646  chrY  62456021  .   G   T   6.5     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598647  chrY  62456075  .   G   T  13.4     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598648  chrY  62456143  .  AG   A   2.6  refCall    .  GT:GQ:DP:AD:VAF:C
# 7598649  chrY  62456186  .  AG   A   6.1     PASS    .  GT:GQ:DP:AD:VAF:C
# 7598650  chrY  62456282  .  AG   A    10     PASS    .  GT:GQ:DP:AD:VAF:C
#
#                         sample  ... DP  AD       VAF   GT      genotype  \
# 0              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 1              1/1:10:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 2              1/1:11:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# 3        0/1:6:3:2:0.666667:DV  ...  3   2  0.666667  0/1  heterozygous
# 4              1/1:13:3:3:1:DV  ...  3   3  1.000000  1/1    homozygous
# ...                        ...  ... ..  ..       ...  ...           ...
# 7598646         1/1:5:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598647         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598648         ./.:3:2:2:1:DV  ...  2   2  1.000000  ./.    homozygous
# 7598649         1/1:4:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
# 7598650         1/1:6:2:2:1:DV  ...  2   2  1.000000  1/1    homozygous
#
#         pass_sample_filters  cosmic_ann  gene protein_position  \
# 0                     False          {}  None             None
# 1                     False          {}  None             None
# 2                     False          {}  None             None
# 3                     False          {}  None             None
# 4                     False          {}  None             None
# ...                     ...         ...   ...              ...
# 7598646               False          {}  None             None
# 7598647               False          {}  None             None
# 7598648               False          {}  None             None
# 7598649               False          {}  None             None
# 7598650               False          {}  None             None
#
#         mutation_description
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 7598646                 None
# 7598647                 None
# 7598648                 None
# 7598649                 None
# 7598650                 None
#
# [7592766 rows x 21 columns]

# %%
df5["qual"] = pd.to_numeric(df5["qual"]).astype(int)

df_fin = df5[
    (df5["filter"] == "PASS") &
    (df5["qual"] > 5) &
    (df5["AD"] > 5) &
    (df5["mutation_description"].notna())
]

df_fin
# Out:
# /tmp/ipykernel_2560507/3975431123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["qual"] = pd.to_numeric(df5["qual"]).astype(int)
#           chr        pos id ref alt  qual filter  \
# 48927    chr1   14950750  .   T   C    24   PASS
# 49000    chr1   14968816  .   G   A    23   PASS
# 102498   chr1   36149695  .   C   T    23   PASS
# 126001   chr1   47138842  .   T   C    19   PASS
# 126115   chr1   47180683  .   G   A    22   PASS
# ...       ...        ... ..  ..  ..   ...    ...
# 7291436  chr9  127266169  .   C   T    24   PASS
# 7291475  chr9  127278662  .   T   C    25   PASS
# 7303539  chr9  133284599  .   G   A    24   PASS
# 7303577  chr9  133294439  .   C   T    27   PASS
# 7511255  chrX   99834591  .   T   C    26   PASS
#
#                                                       info             format  \
# 48927    GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TR...  GT:GQ:DP:AD:VAF:C
# 49000    GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TR...  GT:GQ:DP:AD:VAF:C
# 102498   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TR...  GT:GQ:DP:AD:VAF:C
# 126001   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRAN...  GT:GQ:DP:AD:VAF:C
# 126115   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRAN...  GT:GQ:DP:AD:VAF:C
# ...                                                    ...                ...
# 7291436  GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRAN...  GT:GQ:DP:AD:VAF:C
# 7291475  GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRAN...  GT:GQ:DP:AD:VAF:C
# 7303539  GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TR...  GT:GQ:DP:AD:VAF:C
# 7303577  GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TR...  GT:GQ:DP:AD:VAF:C
# 7511255  GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANS...  GT:GQ:DP:AD:VAF:C
#
#                        sample  ...  DP  AD    VAF   GT      genotype  \
# 48927        1/1:24:29:29:1:P  ...  29  29  1.000  1/1    homozygous
# 49000    1/1:23:27:26:0.963:P  ...  27  26  0.963  1/1    homozygous
# 102498     0/1:23:30:18:0.6:P  ...  30  18  0.600  0/1  heterozygous
# 126001   0/1:19:29:11:0.379:P  ...  29  11  0.379  0/1  heterozygous
# 126115    0/1:22:25:12:0.48:P  ...  25  12  0.480  0/1  heterozygous
# ...                       ...  ...  ..  ..    ...  ...           ...
# 7291436  0/1:24:21:12:0.571:P  ...  21  12  0.571  0/1  heterozygous
# 7291475      1/1:25:32:32:1:P  ...  32  32  1.000  1/1    homozygous
# 7303539      1/1:24:35:35:1:P  ...  35  35  1.000  1/1    homozygous
# 7303577      1/1:27:31:31:1:P  ...  31  31  1.000  1/1    homozygous
# 7511255      1/1:26:22:22:1:P  ...  22  22  1.000  1/1    homozygous
#
#         pass_sample_filters  \
# 48927                  True
# 49000                  True
# 102498                 True
# 126001                 True
# 126115                 True
# ...                     ...
# 7291436                True
# 7291475                True
# 7303539                True
# 7303577                True
# 7511255                True
#
#                                                 cosmic_ann    gene  \
# 48927    {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...   CASP9
# 49000    {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...   CASP9
# 102498   {'GENE_SYMBOL': 'THRAP3', 'COSMIC_GENE_ID': 'C...  THRAP3
# 126001   {'GENE_SYMBOL': 'STIL', 'COSMIC_GENE_ID': 'COS...    STIL
# 126115   {'GENE_SYMBOL': 'STIL', 'COSMIC_GENE_ID': 'COS...    STIL
# ...                                                    ...     ...
# 7291436  {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...     TNC
# 7291475  {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...     TNC
# 7303539  {'GENE_SYMBOL': 'CNTRL', 'COSMIC_GENE_ID': 'CO...   CNTRL
# 7303577  {'GENE_SYMBOL': 'CNTRL', 'COSMIC_GENE_ID': 'CO...   CNTRL
# 7511255  {'GENE_SYMBOL': 'BTK', 'COSMIC_GENE_ID': 'COSG...     BTK
#
#         protein_position                    mutation_description
# 48927            p.Q221R                        missense_variant
# 49000             p.A28V                        missense_variant
# 102498           p.A201V                        missense_variant
# 126001           p.H985R                        missense_variant
# 126115            p.A86V                        missense_variant
# ...                  ...                                     ...
# 7291436         p.R1066H                        missense_variant
# 7291475          p.Q539R                        missense_variant
# 7303539           p.V56I                        missense_variant
# 7303577          p.P216L                        missense_variant
# 7511255           p.E24G  missense_variant,splice_region_variant
#
# [227 rows x 21 columns]

# %%
print(df_fin["mutation_description"].unique())
print(df_fin["gene"].unique())
# Out:
# ['missense_variant' 'intron_variant,splice_region_variant'
#  'missense_variant,splice_region_variant'
#  'splice_region_variant,synonymous_variant' 'stop_gained']
# ['CASP9' 'THRAP3' 'STIL' 'TENT5C' 'NOTCH2' 'BCL9' 'NTRK1' 'FCRL4' 'FCGR2B'
#  'PBX1' 'RGS7' 'BMPR1A' 'NUTM2D' 'MUC6' 'NUP98' 'FAT3' 'DDX10' 'KDM5A'
#  'ERC1' 'CHD4' 'COL2A1' 'ATF1' 'NACA' 'HMGA2' 'PTPRB' 'SETD1B' 'NCOR2'
#  'POLE' 'BAZ1A' 'FOXA1' 'NIN' 'TRIP11' 'GOLGA5' 'BUB1B' 'KNL1' 'NTRK3'
#  'FES' 'CHD2' 'GRIN2A' 'CDH11' 'ZFHX3' 'RFWD3' 'CBFA2T3' 'FANCA' 'USP6'
#  'RABEP1' 'PER1' 'NCOR1' 'SPECC1' 'SUZ12' 'ERBB2' 'RNF43' 'RNF213'
#  'ASPSCR1' 'SETBP1' 'MUC16' 'CEP89' 'ALK' 'BIRC6' 'EPAS1' 'MSH6' 'RGPD3'
#  'RANBP2' 'LRP1B' 'ITGAV' 'ERBB4' 'BARD1' 'CRNKL1' 'PLCG1' 'TMPRSS2' 'ISX'
#  'MRTFA' 'MLH1' 'MITF' 'GATA2' 'ATR' 'WWTR1' 'GMPS' 'MLF1' 'MUC4' 'N4BP2'
#  'KIT' 'AFF1' 'TET2' 'FAT4' 'CASP3' 'FAT1' 'SDHA' 'DROSHA' 'IL7R' 'IL6ST'
#  'RAD17' 'ACSL6' 'FGFR4' 'FLT4' 'HLA-A' 'DAXX' 'CCND3' 'ECT2L' 'EZR'
#  'PMS2' 'EGFR' 'ELN' 'CUX1' 'MET' 'POT1' 'CNTNAP2' 'PCM1' 'WRN' 'NRG1'
#  'NBN' 'CSMD3' 'NDRG1' 'RECQL4' 'GNAQ' 'NTRK2' 'WNK2' 'NR4A3' 'TNC'
#  'CNTRL' 'BTK']

# %%
df_fin.to_csv("/lustre/scratch126/casm/team274sb/lr26/pepper-tumor1B01/normalized_annotated_normalized_tumort2t_filtered_mutated.vcf", sep="\t")

# %%
import pandas as pd
df = pd.read_csv("/lustre/scratch126/casm/team274sb/lr26/pepper-tumor1B01/normalized_annotated_normalized_tumort2t_filtered_mutated.vcf",
                 sep="\t",
                 comment="#",
                 dtype="str",
                 header=None,
                 names=["no", "chr","pos","id","ref","alt","qual","filter","info","format","sample"])
df
# Out:
#                                                                                                                                                                                         no  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                                                      sample_info
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P      {'GT': '1/1', 'GQ': '24', 'DP': 29, 'AD': 29, ...
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P  {'GT': '1/1', 'GQ': '23', 'DP': 27, 'AD': 26, ...
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    {'GT': '0/1', 'GQ': '23', 'DP': 30, 'AD': 18, ...
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  {'GT': '0/1', 'GQ': '19', 'DP': 29, 'AD': 11, ...
# ...                                                                                                                                                                                    ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  {'GT': '0/1', 'GQ': '24', 'DP': 21, 'AD': 12, ...
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P      {'GT': '1/1', 'GQ': '25', 'DP': 32, 'AD': 32, ...
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P      {'GT': '1/1', 'GQ': '24', 'DP': 35, 'AD': 35, ...
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P      {'GT': '1/1', 'GQ': '27', 'DP': 31, 'AD': 31, ...
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P      {'GT': '1/1', 'GQ': '26', 'DP': 22, 'AD': 22, ...
#
#                                                                                                                                         chr  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                DP
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P      29
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P  27
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    30
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  29
# ...                                                                                                                                      ..
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  21
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P      32
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P      35
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P      31
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P      22
#
#                                                                                                                                         pos  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                AD
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P      29
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P  26
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    18
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  11
# ...                                                                                                                                      ..
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  12
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P      32
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P      35
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P      31
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P      22
#
#                                                                                                                                             id  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                  VAF
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P        1.0
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P  0.963
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P      0.6
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  0.379
# ...                                                                                                                                        ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  0.571
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P        1.0
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P        1.0
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P        1.0
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P        1.0
#
#                                                                                                                                          ref  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                 GT
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P      1/1
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P  1/1
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    0/1
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  0/1
# ...                                                                                                                                      ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  0/1
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P      1/1
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P      1/1
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P      1/1
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P      1/1
#
#                                                                                                                                                   alt  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                    genotype
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P        homozygous
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P    homozygous
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    heterozygous
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  heterozygous
# ...                                                                                                                                               ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  heterozygous
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P        homozygous
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P        homozygous
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P        homozygous
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P        homozygous
#
#                                                                                                                                                         qual  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                pass_sample_filters
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P                     True
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P                 True
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P                   True
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P                 True
# ...                                                                                                                                                      ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P                 True
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P                     True
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P                     True
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P                     True
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P                     True
#
#                                                                                                                                                                                     filter  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                                                       cosmic_ann
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P      {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P  {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    {'GENE_SYMBOL': 'THRAP3', 'COSMIC_GENE_ID': 'C...
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P  {'GENE_SYMBOL': 'STIL', 'COSMIC_GENE_ID': 'COS...
# ...                                                                                                                                                                                    ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P  {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P      {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P      {'GENE_SYMBOL': 'CNTRL', 'COSMIC_GENE_ID': 'CO...
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P      {'GENE_SYMBOL': 'CNTRL', 'COSMIC_GENE_ID': 'CO...
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P      {'GENE_SYMBOL': 'BTK', 'COSMIC_GENE_ID': 'COSG...
#
#                                                                                                                                            info  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                  gene
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P       CASP9
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P   CASP9
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P    THRAP3
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P    STIL
# ...                                                                                                                                         ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P     TNC
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P         TNC
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P       CNTRL
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P       CNTRL
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P         BTK
#
#                                                                                                                                                    format  \
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                protein_position
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P               p.Q221R
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P            p.A28V
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P             p.A201V
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P           p.H985R
# ...                                                                                                                                                   ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P          p.R1066H
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P               p.Q539R
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P                p.V56I
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P               p.P216L
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P                p.E24G
#
#                                                                                                                                                                          sample
# NaN     chr  pos       id ref alt qual filter info                                               format            sample                                  mutation_description
# 48927   chr1 14950750  .  T   C   24   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:29:29:1:P                            missense_variant
# 49000   chr1 14968816  .  G   A   23   PASS   GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TRA... GT:GQ:DP:AD:VAF:C 1/1:23:27:26:0.963:P                        missense_variant
# 102498  chr1 36149695  .  C   T   23   PASS   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TRA... GT:GQ:DP:AD:VAF:C 0/1:23:30:18:0.6:P                          missense_variant
# 126001  chr1 47138842  .  T   C   19   PASS   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRANS... GT:GQ:DP:AD:VAF:C 0/1:19:29:11:0.379:P                        missense_variant
# ...                                                                                                                                                                         ...
# 7291436 chr9 127266169 .  C   T   24   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 0/1:24:21:12:0.571:P                        missense_variant
# 7291475 chr9 127278662 .  T   C   25   PASS   GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRANS... GT:GQ:DP:AD:VAF:C 1/1:25:32:32:1:P                            missense_variant
# 7303539 chr9 133284599 .  G   A   24   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:24:35:35:1:P                            missense_variant
# 7303577 chr9 133294439 .  C   T   27   PASS   GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TRA... GT:GQ:DP:AD:VAF:C 1/1:27:31:31:1:P                            missense_variant
# 7511255 chrX 99834591  .  T   C   26   PASS   GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANSC... GT:GQ:DP:AD:VAF:C 1/1:26:22:22:1:P      missense_variant,splice_region_variant
#
# [228 rows x 11 columns]

# %%
print(df["sample"].unique())
print(df["info"].unique())
# Out:
# ['mutation_description' 'missense_variant'
#  'intron_variant,splice_region_variant'
#  'missense_variant,splice_region_variant'
#  'splice_region_variant,synonymous_variant' 'stop_gained']
# ['gene' 'CASP9' 'THRAP3' 'STIL' 'TENT5C' 'NOTCH2' 'BCL9' 'NTRK1' 'FCRL4'
#  'FCGR2B' 'PBX1' 'RGS7' 'BMPR1A' 'NUTM2D' 'MUC6' 'NUP98' 'FAT3' 'DDX10'
#  'KDM5A' 'ERC1' 'CHD4' 'COL2A1' 'ATF1' 'NACA' 'HMGA2' 'PTPRB' 'SETD1B'
#  'NCOR2' 'POLE' 'BAZ1A' 'FOXA1' 'NIN' 'TRIP11' 'GOLGA5' 'BUB1B' 'KNL1'
#  'NTRK3' 'FES' 'CHD2' 'GRIN2A' 'CDH11' 'ZFHX3' 'RFWD3' 'CBFA2T3' 'FANCA'
#  'USP6' 'RABEP1' 'PER1' 'NCOR1' 'SPECC1' 'SUZ12' 'ERBB2' 'RNF43' 'RNF213'
#  'ASPSCR1' 'SETBP1' 'MUC16' 'CEP89' 'ALK' 'BIRC6' 'EPAS1' 'MSH6' 'RGPD3'
#  'RANBP2' 'LRP1B' 'ITGAV' 'ERBB4' 'BARD1' 'CRNKL1' 'PLCG1' 'TMPRSS2' 'ISX'
#  'MRTFA' 'MLH1' 'MITF' 'GATA2' 'ATR' 'WWTR1' 'GMPS' 'MLF1' 'MUC4' 'N4BP2'
#  'KIT' 'AFF1' 'TET2' 'FAT4' 'CASP3' 'FAT1' 'SDHA' 'DROSHA' 'IL7R' 'IL6ST'
#  'RAD17' 'ACSL6' 'FGFR4' 'FLT4' 'HLA-A' 'DAXX' 'CCND3' 'ECT2L' 'EZR'
#  'PMS2' 'EGFR' 'ELN' 'CUX1' 'MET' 'POT1' 'CNTNAP2' 'PCM1' 'WRN' 'NRG1'
#  'NBN' 'CSMD3' 'NDRG1' 'RECQL4' 'GNAQ' 'NTRK2' 'WNK2' 'NR4A3' 'TNC'
#  'CNTRL' 'BTK']

# %%
mlem = (df["info"].value_counts())
print(mlem[mlem > 1])
# Out:
# info
# MUC16     46
# FANCA      9
# FAT1       6
# FGFR4      5
# RNF213     4
# CRNKL1     4
# RGPD3      4
# CSMD3      4
# MUC6       3
# SPECC1     3
# ALK        3
# SDHA       3
# TNC        3
# ZFHX3      2
# PTPRB      2
# CUX1       2
# HLA-A      2
# KIT        2
# PER1       2
# RFWD3      2
# USP6       2
# STIL       2
# NTRK1      2
# NACA       2
# NUTM2D     2
# CASP9      2
# LRP1B      2
# MLF1       2
# N4BP2      2
# IL6ST      2
# PMS2       2
# NBN        2
# CNTRL      2
# CCND3      2
# PCM1       2
# Name: count, dtype: int64

# %%
"/lustre/scratch126/casm/team274sb/lr26/pepper-tumor1B01/normalized_annotated_shared_germline_new_filtered_mutated.vcf"
"/lustre/scratch126/casm/team274sb/lr26/pepper-tumor1B01/normalized_annotated_tumor_somatic_new_filtered_mutated.vcf"
"/lustre/scratch126/casm/team274sb/lr26/pepper-tumor38/normalized_annotated_shared_germline_new_filtered_mutated.vcf"
"/lustre/scratch126/casm/team274sb/lr26/pepper-tumor38/normalized_annotated_tumor_somatic_new_filtered_mutated.vcf"

# %%
colnames = ["unnamed", "chr", "pos", "ref", "alt", "count", "gene_symbol", "mutation_aa", "mutation_description"]
t2t_df = pd.read_csv("/lustre/scratch126/casm/team274sb/lr26/T2T/cosmic_summary_hotspots_t2t.tsv", sep="\t", dtype=str, names = colnames)  # Adjust path/columns as needed
hg38_df = pd.read_csv("/lustre/scratch126/casm/team274sb/lr26/hg38/cosmic_summary_hotspots_hg38.tsv", sep="\t", dtype=str, names = colnames)  # Adjust path/columns as needed

# %%
t2t_df
# Out:
#       unnamed    chr        pos     ref  alt  count  gene_symbol  \
# 0         NaN  CHROM        POS     REF  ALT  COUNT  GENE_SYMBOL
# 1         704   chr1    1998343       G    A     12     TNFRSF14
# 2         753   chr1    1999405       C    T     12     TNFRSF14
# 3         893   chr1    2001410       C    T     31     TNFRSF14
# 4        1119   chr1    2004535       G    A     22     TNFRSF14
# ...       ...    ...        ...     ...  ...    ...          ...
# 5499  1077914   chrX  132740258       G    A     16         PHF6
# 5500  1078007   chrX  132742440       C    T     23         PHF6
# 5501  1078505   chrX  151822337  GCTGGT    G     13       ATP2B3
# 5502  1078857   chrX  151833356       C    T     14       ATP2B3
# 5503  1080864   chrX  152636424       C    A     43        RPL10
#
#          mutation_aa  mutation_description
# 0        MUTATION_AA  MUTATION_DESCRIPTION
# 1             p.W12*           stop_gained
# 2             p.Y35=    synonymous_variant
# 3                p.?        intron_variant
# 4            p.V241I      missense_variant
# ...              ...                   ...
# 5499         p.R274Q      missense_variant
# 5500         p.R319*           stop_gained
# 5501  p.L425_V426del      inframe_deletion
# 5502         p.T901M      missense_variant
# 5503          p.R98S      missense_variant
#
# [5504 rows x 9 columns]

# %%
df_fin
# Out:
#           chr        pos id ref alt  qual filter  \
# 48927    chr1   14950750  .   T   C    24   PASS
# 49000    chr1   14968816  .   G   A    23   PASS
# 102498   chr1   36149695  .   C   T    23   PASS
# 126001   chr1   47138842  .   T   C    19   PASS
# 126115   chr1   47180683  .   G   A    22   PASS
# ...       ...        ... ..  ..  ..   ...    ...
# 7291436  chr9  127266169  .   C   T    24   PASS
# 7291475  chr9  127278662  .   T   C    25   PASS
# 7303539  chr9  133284599  .   G   A    24   PASS
# 7303577  chr9  133294439  .   C   T    27   PASS
# 7511255  chrX   99834591  .   T   C    26   PASS
#
#                                                       info             format  \
# 48927    GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TR...  GT:GQ:DP:AD:VAF:C
# 49000    GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TR...  GT:GQ:DP:AD:VAF:C
# 102498   GENE_SYMBOL=THRAP3;COSMIC_GENE_ID=COSG77463;TR...  GT:GQ:DP:AD:VAF:C
# 126001   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRAN...  GT:GQ:DP:AD:VAF:C
# 126115   GENE_SYMBOL=STIL;COSMIC_GENE_ID=COSG80911;TRAN...  GT:GQ:DP:AD:VAF:C
# ...                                                    ...                ...
# 7291436  GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRAN...  GT:GQ:DP:AD:VAF:C
# 7291475  GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRAN...  GT:GQ:DP:AD:VAF:C
# 7303539  GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TR...  GT:GQ:DP:AD:VAF:C
# 7303577  GENE_SYMBOL=CNTRL;COSMIC_GENE_ID=COSG105745;TR...  GT:GQ:DP:AD:VAF:C
# 7511255  GENE_SYMBOL=BTK;COSMIC_GENE_ID=COSG96537;TRANS...  GT:GQ:DP:AD:VAF:C
#
#                        sample  ...  DP  AD    VAF   GT      genotype  \
# 48927        1/1:24:29:29:1:P  ...  29  29  1.000  1/1    homozygous
# 49000    1/1:23:27:26:0.963:P  ...  27  26  0.963  1/1    homozygous
# 102498     0/1:23:30:18:0.6:P  ...  30  18  0.600  0/1  heterozygous
# 126001   0/1:19:29:11:0.379:P  ...  29  11  0.379  0/1  heterozygous
# 126115    0/1:22:25:12:0.48:P  ...  25  12  0.480  0/1  heterozygous
# ...                       ...  ...  ..  ..    ...  ...           ...
# 7291436  0/1:24:21:12:0.571:P  ...  21  12  0.571  0/1  heterozygous
# 7291475      1/1:25:32:32:1:P  ...  32  32  1.000  1/1    homozygous
# 7303539      1/1:24:35:35:1:P  ...  35  35  1.000  1/1    homozygous
# 7303577      1/1:27:31:31:1:P  ...  31  31  1.000  1/1    homozygous
# 7511255      1/1:26:22:22:1:P  ...  22  22  1.000  1/1    homozygous
#
#         pass_sample_filters  \
# 48927                  True
# 49000                  True
# 102498                 True
# 126001                 True
# 126115                 True
# ...                     ...
# 7291436                True
# 7291475                True
# 7303539                True
# 7303577                True
# 7511255                True
#
#                                                 cosmic_ann    gene  \
# 48927    {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...   CASP9
# 49000    {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...   CASP9
# 102498   {'GENE_SYMBOL': 'THRAP3', 'COSMIC_GENE_ID': 'C...  THRAP3
# 126001   {'GENE_SYMBOL': 'STIL', 'COSMIC_GENE_ID': 'COS...    STIL
# 126115   {'GENE_SYMBOL': 'STIL', 'COSMIC_GENE_ID': 'COS...    STIL
# ...                                                    ...     ...
# 7291436  {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...     TNC
# 7291475  {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...     TNC
# 7303539  {'GENE_SYMBOL': 'CNTRL', 'COSMIC_GENE_ID': 'CO...   CNTRL
# 7303577  {'GENE_SYMBOL': 'CNTRL', 'COSMIC_GENE_ID': 'CO...   CNTRL
# 7511255  {'GENE_SYMBOL': 'BTK', 'COSMIC_GENE_ID': 'COSG...     BTK
#
#         protein_position                    mutation_description
# 48927            p.Q221R                        missense_variant
# 49000             p.A28V                        missense_variant
# 102498           p.A201V                        missense_variant
# 126001           p.H985R                        missense_variant
# 126115            p.A86V                        missense_variant
# ...                  ...                                     ...
# 7291436         p.R1066H                        missense_variant
# 7291475          p.Q539R                        missense_variant
# 7303539           p.V56I                        missense_variant
# 7303577          p.P216L                        missense_variant
# 7511255           p.E24G  missense_variant,splice_region_variant
#
# [227 rows x 21 columns]

# %%
annotated_df = pd.merge(df_fin, t2t_df, on=["chr", "pos", "ref", "alt"], how="left")
# Merge VCF and annotation TSV
annotated_df = annotated_df[annotated_df["count"].notna()]

# %%
annotated_df
# Out:
#        chr        pos id ref alt  qual filter  \
# 0     chr1   14950750  .   T   C    24   PASS
# 1     chr1   14968816  .   G   A    23   PASS
# 16   chr10   88248713  .   G   A    20   PASS
# 17   chr11    1076512  .   T   G    24   PASS
# 19   chr11    1097695  .   C   T    22   PASS
# ..     ...        ... ..  ..  ..   ...    ...
# 209   chr8   91069483  .   T   C    25   PASS
# 210   chr8   91101432  .   C   G    26   PASS
# 216   chr8  145685942  .   T   A    17   PASS
# 219   chr9  105426425  .   G   A    24   PASS
# 221   chr9  127222877  .   C   G    21   PASS
#
#                                                   info             format  \
# 0    GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TR...  GT:GQ:DP:AD:VAF:C
# 1    GENE_SYMBOL=CASP9;COSMIC_GENE_ID=COSG102681;TR...  GT:GQ:DP:AD:VAF:C
# 16   GENE_SYMBOL=NUTM2D;COSMIC_GENE_ID=COSG61484;TR...  GT:GQ:DP:AD:VAF:C
# 17   GENE_SYMBOL=MUC6;COSMIC_GENE_ID=COSG58094;TRAN...  GT:GQ:DP:AD:VAF:C
# 19   GENE_SYMBOL=MUC6;COSMIC_GENE_ID=COSG58094;TRAN...  GT:GQ:DP:AD:VAF:C
# ..                                                 ...                ...
# 209  GENE_SYMBOL=NBN;COSMIC_GENE_ID=COSG81202;TRANS...  GT:GQ:DP:AD:VAF:C
# 210  GENE_SYMBOL=NBN;COSMIC_GENE_ID=COSG81202;TRANS...  GT:GQ:DP:AD:VAF:C
# 216  GENE_SYMBOL=RECQL4;COSMIC_GENE_ID=COSG81638;TR...  GT:GQ:DP:AD:VAF:C
# 219  GENE_SYMBOL=WNK2;COSMIC_GENE_ID=COSG97812;TRAN...  GT:GQ:DP:AD:VAF:C
# 221  GENE_SYMBOL=TNC;COSMIC_GENE_ID=COSG105617;TRAN...  GT:GQ:DP:AD:VAF:C
#
#                    sample  ... pass_sample_filters  \
# 0        1/1:24:29:29:1:P  ...                True
# 1    1/1:23:27:26:0.963:P  ...                True
# 16   0/1:20:38:22:0.579:P  ...                True
# 17   0/1:24:35:20:0.571:P  ...                True
# 19   0/1:22:35:20:0.571:P  ...                True
# ..                    ...  ...                 ...
# 209      1/1:25:26:26:1:P  ...                True
# 210      1/1:26:27:27:1:P  ...                True
# 216   0/1:17:13:7:0.538:P  ...                True
# 219      1/1:24:25:25:1:P  ...                True
# 221  0/1:21:34:22:0.647:P  ...                True
#
#                                             cosmic_ann    gene  \
# 0    {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...   CASP9
# 1    {'GENE_SYMBOL': 'CASP9', 'COSMIC_GENE_ID': 'CO...   CASP9
# 16   {'GENE_SYMBOL': 'NUTM2D', 'COSMIC_GENE_ID': 'C...  NUTM2D
# 17   {'GENE_SYMBOL': 'MUC6', 'COSMIC_GENE_ID': 'COS...    MUC6
# 19   {'GENE_SYMBOL': 'MUC6', 'COSMIC_GENE_ID': 'COS...    MUC6
# ..                                                 ...     ...
# 209  {'GENE_SYMBOL': 'NBN', 'COSMIC_GENE_ID': 'COSG...     NBN
# 210  {'GENE_SYMBOL': 'NBN', 'COSMIC_GENE_ID': 'COSG...     NBN
# 216  {'GENE_SYMBOL': 'RECQL4', 'COSMIC_GENE_ID': 'C...  RECQL4
# 219  {'GENE_SYMBOL': 'WNK2', 'COSMIC_GENE_ID': 'COS...    WNK2
# 221  {'GENE_SYMBOL': 'TNC', 'COSMIC_GENE_ID': 'COSG...     TNC
#
#      protein_position                mutation_description_x  unnamed  count  \
# 0             p.Q221R                      missense_variant    15376     12
# 1              p.A28V                      missense_variant    15518     26
# 16            p.E474K                      missense_variant    90416     25
# 17           p.Q1735H                      missense_variant   106493     23
# 19            p.V619M                      missense_variant   107325     21
# ..                ...                                   ...      ...    ...
# 209               p.?  intron_variant,splice_region_variant   940092     13
# 210           p.E185Q                      missense_variant   940509     27
# 216               p.?  intron_variant,splice_region_variant   986030     25
# 219           p.V828M                      missense_variant  1023119     18
# 221          p.E2008Q                      missense_variant  1028928     11
#
#     gene_symbol mutation_aa                       mutation_description_y
# 0         CASP9     p.Q221R                             missense_variant
# 1         CASP9      p.A28V                             missense_variant
# 16       NUTM2D     p.E474K                             missense_variant
# 17         MUC6    p.Q1735H                             missense_variant
# 19         MUC6     p.V619M                             missense_variant
# ..          ...         ...                                          ...
# 209         NBN         p.?  ('intron_variant', 'splice_region_variant')
# 210         NBN     p.E185Q                             missense_variant
# 216      RECQL4         p.?  ('intron_variant', 'splice_region_variant')
# 219        WNK2     p.V828M                             missense_variant
# 221         TNC    p.E2008Q                             missense_variant
#
# [79 rows x 26 columns]

# %%
annotated_df.to_csv("/lustre/scratch126/casm/team274sb/lr26/pepper-tumor1B01/normalized_annotated_tumort2t_filtered_mutated_hotspots.vcf", sep="\t")
